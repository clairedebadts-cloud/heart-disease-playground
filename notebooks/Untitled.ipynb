# %% [markdown]
# # Data preparation and discovery

# %%
import pandas as pd

pd.read_csv('/users/clairedebadts/kaggle/heart-disease-playground/data/train.csv', nrows=50000).to_csv('/users/clairedebadts/kaggle/heart-disease-playground/data/train_sample.csv', index=False)
